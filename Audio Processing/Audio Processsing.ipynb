# %% [markdown]
# # Audio Processing in Python

# %% [markdown]
# # Some Terminologies
#
# Before starting, let us understand some terminologies related to audio and signal processing which will help in understanding and following this notebook in a better way.
#
# * Analog speech signal : The speech which usually is uttered by humans and is propogated through air.
# * Digital speech signal : The speech (in terms of samples) after performing analog-to-digital conversion using an ADC device. In this form, speech signal is in form of digitized samples.
# * Frequency of a signal : The number of cycles a signal repeats in 1 second duration.
# * Amplitude of a signal : It is related to loudness of speech (for speech signal). Depending on the type of the signal, it can be energy, voltage etc.

# %% [markdown]
# ### Processing a Noisy and Clean Signal
#
# - There are two noisy and clean signals in the same folder
# - Generate MFCC of both the Signals and report the differences

# %%
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np

clean_signal_file="Clean-Signal.wav"
noisy_signal_file="Noisy-Signal.wav"

clean_signal,sr=librosa.load(clean_signal_file)
noisy_signal, _ =librosa.load(noisy_signal_file)

mfcc_noisy = librosa.feature.mfcc(y=noisy_signal, sr=sr, n_mfcc=13)
mfcc_clean = librosa.feature.mfcc(y=clean_signal, sr=sr, n_mfcc=13)

plt.figure(figsize=(12, 12))
plt.subplot(2, 1, 1)
librosa.display.specshow(mfcc_noisy, sr=sr, x_axis='time')
plt.colorbar()
plt.title('MFCCs of Noisy Signal')

plt.subplot(2, 1, 2)
librosa.display.specshow(mfcc_clean, sr=sr, x_axis='time')
plt.colorbar()
plt.title('MFCCs of Clean Signal')

plt.show()

# %% [markdown]
# ### Trimming and Processing the Signal
# - The >Example.wav file contains is of a very large length.
# - Plot the MFCC
# - Trim the first 4 Seconds of Audio and plot the MFCC
# - Observe the Changes

# %%
example_file="Example.wav"
example,sr=librosa.load(example_file)
mfcc_example=librosa.feature.mfcc(y=example, sr=sr, n_mfcc=13)

plt.figure(figsize=(12, 12))
plt.subplot(2, 1, 1)
librosa.display.specshow(mfcc_example, sr=sr, x_axis='time')
plt.colorbar()
plt.title('MFCCs of original file')

trimmed_example=example[4*sr:]
mfcc_trimmed=librosa.feature.mfcc(y=trimmed_example, sr=sr, n_mfcc=13)

plt.subplot(2, 1, 2)
librosa.display.specshow(mfcc_trimmed, sr=sr, x_axis='time')
plt.colorbar()
plt.title('MFCCs of trimmed file')

plt.show()
